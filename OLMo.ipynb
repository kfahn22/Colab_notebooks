# %% [markdown]
# <a href="https://colab.research.google.com/github/kfahn22/Colab_notebooks/blob/main/OLMo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # OLMo
#
# * [OLMo](https://github.com/allenai/OLMo) is an open-source LLM developed by Allen Institute for Artificial Intelligence.  It was introduced in [OLMo: Accelerating the Science of Language Models](https://arxiv.org/pdf/2402.00838.pdf) by Groeneveld, et. al.
#
# * [Tonic's Olmo-on-Device](https://huggingface.co/spaces/Tonic/Olmo)

# %%
# !pip install ai2-olmo transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.5/113.5 kB 3.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 10.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 16.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 70.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 10.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.7/311.7 kB 37.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 16.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=c5ba442620ccb3caf68f742d9121f5bed0b8fbef036be1c3c27c533a5d788ee1
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
# Successfully built antlr4-python3-runtime
# ...

# %% [markdown]
# Note: bitsandbytes accelerate are necessary for quantization.
#
# I think you need a T4 for this.

# %%
#!pip install ai2-olmo transformers bitsandbytes accelerate
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.5/113.5 kB 2.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.0/105.0 MB 15.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.0/280.0 kB 31.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 10.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 15.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 84.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 10.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.7/311.7 kB 35.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 16.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=17fca5f6cc09c4b26425d64e7bda7f95df00c9014607fe042656850fd431c071
# ...

# %%
# %%time
from hf_olmo import * # registers the Auto* classes
import gc
from transformers import AutoModelForCausalLM, AutoTokenizer

model = AutoModelForCausalLM.from_pretrained("allenai/OLMo-7B")
tokenizer = AutoTokenizer.from_pretrained("allenai/OLMo-7B")

message = ["Language modeling is "]
inputs = tokenizer(message, return_tensors='pt', return_token_type_ids=False)
response = model.generate(**inputs, max_new_tokens=100, do_sample=True, top_k=50, top_p=0.95)
print(tokenizer.batch_decode(response, skip_special_tokens=True)[0])
gc.collect()
# Out:
# config.json:   0%|          | 0.00/1.32k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/27.6G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/5.49k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.12M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# Language modeling is
# in its infancy. In particular, models for word and sentence
# sequences are usually based on Markov chains which
# assume that there is no dependence between the hidden states
# in adjacent time intervals. In this article, we will compare a
# typical Markov chain model to a more complex recurrent
# neural network which takes advantage of the dependence
# between the hidden states of adjacent time intervals. We
# will show that the recurrent model offers advantages for
# word
# CPU times: user 6min 5s, sys: 1min 26s, total: 7min 31s
# Wall time: 5min 35s
# 30

# %% [markdown]
# OR from pipeline. Don't run both!

# %%
from transformers import pipeline
olmo_pipe = pipeline("text-generation", model="allenai/OLMo-7B")
print(olmo_pipe("The Coding Train is"))

# %% [markdown]
# From https://huggingface.co/spaces/Tonic/Olmo/blob/main/app.py

# %%
model_name = "allenai/OLMo-1B"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

def generate_text(prompt, max_new_tokens, top_k, top_p, do_sample):
    inputs = tokenizer(prompt, return_tensors='pt', return_token_type_ids=False)
    response = model.generate(**inputs, max_new_tokens=max_new_tokens, do_sample=do_sample, top_k=top_k, top_p=top_p)
    return tokenizer.batch_decode(response, skip_special_tokens=True)[0]

# %%
import torch

# Use GPU if available
if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

# %% [markdown]
# ## Quantization
#
# * [Quantization Documentation on HF hub](https://huggingface.co/docs/transformers/main/en/main_classes/quantization)
#
# * [More on Quantization Documentation on HF hub](https://huggingface.co/docs/transformers/main/en/quantization)
#
# * [A Gentle Introduction to 8-bit Matrix Multiplication for transformers at scale using Hugging Face Transformers, Accelerate and bitsandbytes](https://huggingface.co/blog/hf-bitsandbytes-integration)

# %% [markdown]
# I am not sure whether quantization is necessary is this case.  Getting a CUDA out of memory error.
#
#
# - [Cuda docs](https://pytorch.org/docs/stable/notes/cuda.html)
#
# - [memory-management-using-pytorch-cuda](https://iamholumeedey007.medium.com/memory-management-using-pytorch-cuda-alloc-conf-dabe7adec130)
#
# - [debugging-cuda-out-of-memory](https://forums.fast.ai/t/debugging-cuda-out-of-memory-16gb-gpu-14-gb-reserved/109225/3)

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig

quantization_config = BitsAndBytesConfig(llm_int8_enable_fp32_cpu_offload=True)

# %%
device_map = {
    "transformer.word_embeddings": 0,
    "transformer.word_embeddings_layernorm": 0,
    "lm_head": "cpu",
    "transformer.h": 0,
    "transformer.ln_f": 0,
}

# %%
import gc
from hf_olmo import * # registers the Auto* classes

# from transformers import AutoModelForCausalLM, AutoTokenizer

#model = AutoModelForCausalLM.from_pretrained("allenai/OLMo-7B", torch_dtype=torch.float16, load_in_8bit=True)  # requires bitsandbytes
model = AutoModelForCausalLM.from_pretrained("allenai/OLMo-7B", device_map="auto", load_in_8bit=True)  # requires bitsandbytes
tokenizer = AutoTokenizer.from_pretrained("allenai/OLMo-7B")
message = ["Language modeling is "]
#inputs.input_ids.to('cuda')
inputs = tokenizer(message, return_tensors='pt').input_ids.to(device)
model.generate(**inputs, max_new_tokens=100, do_sample=True, top_k=50, top_p=0.95)


gc.collect()
torch.cuda.empty_cache()
# Out:
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# <ipython-input-3-638c74b84f9d> in <cell line: 7>()
#       5
#       6
# ----> 7 olmo = AutoModelForCausalLM.from_pretrained("allenai/OLMo-7B", torch_dtype=torch.float16, load_in_8bit=True)  # requires bitsandbytes
#       8 tokenizer = AutoTokenizer.from_pretrained("allenai/OLMo-7B")
#       9 message = ["Language modeling is "]
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     564         elif type(config) in cls._model_mapping.keys():
#     565             model_class = _get_model_class(config, cls._model_mapping)
# --> 566             return model_class.from_pretrained(
#     567                 pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     568             )
#
# ...

# %% [markdown]
# From [here](https://iamholumeedey007.medium.com/memory-management-using-pytorch-cuda-alloc-conf-dabe7adec130)

# %%
import torch
import os

# Set PYTORCH_CUDA_ALLOC_CONF environment variable
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "caching_allocator"

# Explanation: By setting PYTORCH_CUDA_ALLOC_CONF to "caching_allocator",
# we enable the caching memory allocator, which improves memory management efficiency.

# Create a CUDA tensor
x = torch.randn(1000, 1000).cuda()

# Explanation: Here, we create a CUDA tensor using the torch.randn() function.
# Since PYTORCH_CUDA_ALLOC_CONF is set, the tensor will be allocated using the caching allocator.

# Perform some computations
y = x + x.t()
z = torch.matmul(y, y)

# Explanation: We perform some computations on the CUDA tensor.
# The caching allocator manages the memory allocation and reuse efficiently,
# reducing the overhead of memory allocation and deallocation operations.

# Clear memory explicitly (optional)
del x, y, z

# Explanation: Clearing the variables is optional, but it can help release GPU memory
# before subsequent operations to avoid excessive memory usage.

# Reset PYTORCH_CUDA_ALLOC_CONF environment variable (optional)
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = ""

# Explanation: Resetting PYTORCH_CUDA_ALLOC_CONF to an empty string restores
# the default memory allocator behavior in PyTorch.

# Continue with other operations
